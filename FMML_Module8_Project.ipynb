# %%
# !pip install PyMuPDF scikit-learn pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 52.0 MB/s eta 0:00:00
# ...

# %%
import fitz  # PyMuPDF
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
# Load the CSV dataset
df = pd.read_csv('/content/resume-dataset.csv')
df = df[['Resume', 'Category']]
df.dropna(inplace=True)

df.head()
# Out:
#                                               Resume      Category
# 0  AnimeshSinha AnimeshSinha AnimeshSinha Animesh...  Data Science
# 1  Skills * Programming Languages: Python (pandas...  Data Science
# 2  Education Details \r\nMay 2013 to May 2017 B.E...  Data Science
# 3  Areas of Interest Deep Learning, Control Syste...  Data Science
# 4  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...  Data Science

# %%
X = df['Resume']
y = df['Category']

# Convert text to TF-IDF features
vectorizer = TfidfVectorizer(stop_words='english', max_features=3000)
X_vectorized = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

model = MultinomialNB()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#                            precision    recall  f1-score   support
#
#                  Advocate       1.00      0.33      0.50         3
#                      Arts       1.00      1.00      1.00         6
#        Automation Testing       1.00      1.00      1.00         6
#                Blockchain       1.00      1.00      1.00         5
#          Business Analyst       1.00      1.00      1.00         5
#            Civil Engineer       1.00      0.70      0.82        10
#              Data Science       1.00      1.00      1.00         5
#                  Database       1.00      1.00      1.00         7
#           DevOps Engineer       1.00      1.00      1.00        13
#          DotNet Developer       1.00      0.86      0.92         7
#             ETL Developer       1.00      1.00      1.00         9
#    Electrical Engineering       1.00      1.00      1.00         5
#                        HR       1.00      1.00      1.00        12
# ...

# %%
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ''
    for page in doc:
        text += page.get_text()
    return text

# Load uploaded resume
pdf_path = "/content/computers_2.pdf"  # change this for other PDFs
resume_text = extract_text_from_pdf(pdf_path)

# Vectorize and predict
resume_vector = vectorizer.transform([resume_text])
prediction = model.predict(resume_vector)

print(f"Predicted Job Category: {prediction[0]}")
# Out:
# Predicted Job Category: Data Science
